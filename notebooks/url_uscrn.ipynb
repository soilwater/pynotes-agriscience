# %% [markdown]
# # Climate Reference Network
#
# Example of retrieving data from the US Climate reference Network
#
#
# ## Documentation
#
# Daily data: https://www1.ncdc.noaa.gov/pub/data/uscrn/products/daily01/
#
# Daily data documentation: https://www1.ncdc.noaa.gov/pub/data/uscrn/products/daily01/README.txt
#
# ## Reference
#
# - Diamond, H. J., T. R. Karl, M. A. Palecki, C. B. Baker, J. E. Bell, R. D. Leeper, D. R. Easterling, J. H. Lawrimore, T. P. Meyers, M. R. Helfert, G. Goodge, and P. W. Thorne, 2013: U.S. Climate Reference Network after one decade of operations: status and assessment. Bull. Amer. Meteor. Soc., 94, 489-498. doi: 10.1175/BAMS-D-12-00170.1

# %%
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# URL link and header variables
url = 'https://www1.ncdc.noaa.gov/pub/data/uscrn/products/daily01/2018/CRND0103-2018-KS_Manhattan_6_SSW.txt'
header_names = ['WBANNO','LST_DATE','CRX_VN','LONGITUDE','LATITUDE','T_DAILY_MAX','T_DAILY_MIN','T_DAILY_MEAN','T_DAILY_AVG','P_DAILY_CALC','SOLARAD_DAILY','SUR_TEMP_DAILY_TYPE','SUR_TEMP_DAILY_MAX','SUR_TEMP_DAILY_MIN','SUR_TEMP_DAILY_AVG','RH_DAILY_MAX','RH_DAILY_MIN','RH_DAILY_AVG','SOIL_MOISTURE_5_DAILY','SOIL_MOISTURE_10_DAILY','SOIL_MOISTURE_20_DAILY','SOIL_MOISTURE_50_DAILY','SOIL_MOISTURE_100_DAILY','SOIL_TEMP_5_DAILY','SOIL_TEMP_10_DAILY','SOIL_TEMP_20_DAILY','SOIL_TEMP_50_DAILY','SOIL_TEMP_100_DAILY'];

# %%
# Read fixed width data
df = pd.read_fwf(url, names=header_names)
df.head(5)
# Out:
#    WBANNO  LST_DATE  CRX_VN  LONGITUDE  LATITUDE  T_DAILY_MAX  T_DAILY_MIN  \
# 0   53974  20180101   2.422     -96.61      39.1        -11.0        -23.4
# 1   53974  20180102   2.422     -96.61      39.1         -4.4        -20.8
# 2   53974  20180103   2.422     -96.61      39.1         -1.5        -13.3
# 3   53974  20180104   2.422     -96.61      39.1          3.2        -16.3
# 4   53974  20180105   2.422     -96.61      39.1         -0.6        -11.9
#
#    T_DAILY_MEAN  T_DAILY_AVG  P_DAILY_CALC         ...           \
# 0         -17.2        -17.1           0.0         ...
# 1         -12.6        -11.6           0.0         ...
# 2          -7.4         -6.1           0.0         ...
# 3          -6.5         -6.5           0.0         ...
# 4          -6.2         -6.7           0.0         ...
#
#    SOIL_MOISTURE_5_DAILY SOIL_MOISTURE_10_DAILY  SOIL_MOISTURE_20_DAILY  \
# 0                  -99.0                  -99.0                   -99.0
# 1                  -99.0                  -99.0                   -99.0
# 2                  -99.0                  -99.0                   -99.0
# 3                  -99.0                  -99.0                   -99.0
# 4                  -99.0                  -99.0                   -99.0
#
#    SOIL_MOISTURE_50_DAILY  SOIL_MOISTURE_100_DAILY  SOIL_TEMP_5_DAILY  \
# 0                   -99.0                    -99.0               -2.7
# 1                   -99.0                    -99.0               -2.5
# 2                   -99.0                    -99.0               -1.8
# 3                   -99.0                    -99.0               -1.9
# 4                   -99.0                    -99.0               -1.6
#
#    SOIL_TEMP_10_DAILY  SOIL_TEMP_20_DAILY  SOIL_TEMP_50_DAILY  \
# 0                -0.8                 0.8             -9999.0
# 1                -1.0                 0.1             -9999.0
# 2                -0.7                -0.1             -9999.0
# 3                -0.8                -0.2             -9999.0
# 4                -0.6                -0.1             -9999.0
#
#    SOIL_TEMP_100_DAILY
# 0              -9999.0
# 1              -9999.0
# 2              -9999.0
# 3              -9999.0
# 4              -9999.0
#
# [5 rows x 28 columns]

# %%
# Convert date from string to datetime format
df['LST_DATE'] = pd.to_datetime(df['LST_DATE'],format='%Y%m%d')
df.head(5)
# Out:
#    WBANNO   LST_DATE  CRX_VN  LONGITUDE  LATITUDE  T_DAILY_MAX  T_DAILY_MIN  \
# 0   53974 2018-01-01   2.422     -96.61      39.1        -11.0        -23.4
# 1   53974 2018-01-02   2.422     -96.61      39.1         -4.4        -20.8
# 2   53974 2018-01-03   2.422     -96.61      39.1         -1.5        -13.3
# 3   53974 2018-01-04   2.422     -96.61      39.1          3.2        -16.3
# 4   53974 2018-01-05   2.422     -96.61      39.1         -0.6        -11.9
#
#    T_DAILY_MEAN  T_DAILY_AVG  P_DAILY_CALC         ...           \
# 0         -17.2        -17.1           0.0         ...
# 1         -12.6        -11.6           0.0         ...
# 2          -7.4         -6.1           0.0         ...
# 3          -6.5         -6.5           0.0         ...
# 4          -6.2         -6.7           0.0         ...
#
#    SOIL_MOISTURE_5_DAILY SOIL_MOISTURE_10_DAILY  SOIL_MOISTURE_20_DAILY  \
# 0                  -99.0                  -99.0                   -99.0
# 1                  -99.0                  -99.0                   -99.0
# 2                  -99.0                  -99.0                   -99.0
# 3                  -99.0                  -99.0                   -99.0
# 4                  -99.0                  -99.0                   -99.0
#
#    SOIL_MOISTURE_50_DAILY  SOIL_MOISTURE_100_DAILY  SOIL_TEMP_5_DAILY  \
# 0                   -99.0                    -99.0               -2.7
# 1                   -99.0                    -99.0               -2.5
# 2                   -99.0                    -99.0               -1.8
# 3                   -99.0                    -99.0               -1.9
# 4                   -99.0                    -99.0               -1.6
#
#    SOIL_TEMP_10_DAILY  SOIL_TEMP_20_DAILY  SOIL_TEMP_50_DAILY  \
# 0                -0.8                 0.8             -9999.0
# 1                -1.0                 0.1             -9999.0
# 2                -0.7                -0.1             -9999.0
# 3                -0.8                -0.2             -9999.0
# 4                -0.6                -0.1             -9999.0
#
#    SOIL_TEMP_100_DAILY
# 0              -9999.0
# 1              -9999.0
# 2              -9999.0
# 3              -9999.0
# 4              -9999.0
#
# [5 rows x 28 columns]

# %%
# Replace missing values (-99 and -9999)
df = df.replace(-9999, np.nan)
df = df.replace(-99, np.nan)
df = df.replace(999, np.nan)
df.head(5)
# Out:
#    WBANNO   LST_DATE  CRX_VN  LONGITUDE  LATITUDE  T_DAILY_MAX  T_DAILY_MIN  \
# 0   53974 2018-01-01   2.422     -96.61      39.1        -11.0        -23.4
# 1   53974 2018-01-02   2.422     -96.61      39.1         -4.4        -20.8
# 2   53974 2018-01-03   2.422     -96.61      39.1         -1.5        -13.3
# 3   53974 2018-01-04   2.422     -96.61      39.1          3.2        -16.3
# 4   53974 2018-01-05   2.422     -96.61      39.1         -0.6        -11.9
#
#    T_DAILY_MEAN  T_DAILY_AVG  P_DAILY_CALC         ...           \
# 0         -17.2        -17.1           0.0         ...
# 1         -12.6        -11.6           0.0         ...
# 2          -7.4         -6.1           0.0         ...
# 3          -6.5         -6.5           0.0         ...
# 4          -6.2         -6.7           0.0         ...
#
#    SOIL_MOISTURE_5_DAILY SOIL_MOISTURE_10_DAILY  SOIL_MOISTURE_20_DAILY  \
# 0                    NaN                    NaN                     NaN
# 1                    NaN                    NaN                     NaN
# 2                    NaN                    NaN                     NaN
# 3                    NaN                    NaN                     NaN
# 4                    NaN                    NaN                     NaN
#
#    SOIL_MOISTURE_50_DAILY  SOIL_MOISTURE_100_DAILY  SOIL_TEMP_5_DAILY  \
# 0                     NaN                      NaN               -2.7
# 1                     NaN                      NaN               -2.5
# 2                     NaN                      NaN               -1.8
# 3                     NaN                      NaN               -1.9
# 4                     NaN                      NaN               -1.6
#
#    SOIL_TEMP_10_DAILY  SOIL_TEMP_20_DAILY  SOIL_TEMP_50_DAILY  \
# 0                -0.8                 0.8                 NaN
# 1                -1.0                 0.1                 NaN
# 2                -0.7                -0.1                 NaN
# 3                -0.8                -0.2                 NaN
# 4                -0.6                -0.1                 NaN
#
#    SOIL_TEMP_100_DAILY
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 28 columns]

# %%
# Plot figure
plt.figure(figsize=(12,6))
plt.plot(df.LST_DATE,df.T_DAILY_AVG,'-k')
plt.plot(df.LST_DATE,df.T_DAILY_MAX, '--r')
plt.plot(df.LST_DATE,df.T_DAILY_MIN, '--b')
plt.axhline(df.T_DAILY_AVG.mean())
plt.ylabel('Air temperature (degrees Celsius)')
plt.legend(['Tavg','Tmax','Tmin'])
plt.show()
